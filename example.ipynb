# %% [markdown]
# # Markdown

# %% [markdown]
# $$ \text{Markdown} \quad \text{+} \quad \text{LaTeX} \quad \text{+} \quad \text{Mermaid} \quad \text{+} \quad \text{TikZ} $$

# %%
def fibonacci(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)
print(fibonacci(10))
# Out:
# 55

# %% [markdown]
# ```mermaid
# graph TD
#     A[矩形] --> B(圆形)
#     A --> C{三角形}
#     B --> D[填充蓝色]
#     C --> E[填充红色]
# ```
